# %% [markdown]
# # if / else

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
true / false

# %%
a = 10
b = 5

# %%
a > b
# Out:
# True

# %%
if 10 > 5:
    print("a is t=greater then b")
else:
    print("a is less then b")
# Out:
# a is t=greater then b

# %%
a = int(input("enter your age: "))

if a >= 18:
    print("bahi cnic banwa lo apna")
else:
    print("bachy ho abhi")
# Out:
# enter your age: 18
# bahi cnic banwa lo apna

# %%
a = input("card lay ho? yes/no  ").lower()
if a =='yes':
    print("jao class ly lo")
else: 
    print("wpis jao")
# Out:
# card lay ho? yes/no  ni sir ghar bool gia
# wpis jao

# %%
a = input("")

if a>"10":
    print("hello")
else:
    print("hajah")
# Out:
# 09347
# hajah

# %%
user_input = int(input("enter your battery numbers: "))
print(f"""user mobile battery: {user_input}""")
if user_input <=5:
    print("charge kr ly bahi!!!!!!!")
else: 
    print("reels scroll kr bahi aram sy!!!?")
# Out:
# enter your battery numbers: 100
# user mobile battery: 100
# reels scroll kr bahi aram sy!!!?

# %%
a = int(input("electricity kitnsy ghanty ati hai??? "))
if a >= 12 :
    print("mazy karo bahuiii")
else:
    print("solar agwa lo")
# Out:
# electricity kitny ghanty ati hai??? 12
# mazy karo bahuiii
