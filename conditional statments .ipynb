# %% [markdown]
# # nested if else

# %%
class_day = input("aj class ka din hai??Y/N")
if class_day =="y":
    card = input("card lay ho ya ni lay??Y/N")
    if card == "y":
        fees = input("fees jama krwa de??Y/N")
        if fees =="y":
            assigment = input("assigment complete?Y/N")
            if assigment =="y":
                print("class ly skty ho")
            else:
                print("assigment complete ni hai, class ni ly skty  ")
        else:
            print("fees jama ni krwai class ni ly skty ")
    else:
        print("card ni lay class ni ly skty ")
else:
    print("class day nahi hai aj,class ni ly skty ")
# Out:
# aj class ka din hai??Y/Ny
# card lay ho ya ni lay??Y/Ny
# fees jama krwa de??Y/Ny
# assigment complete?Y/Ny
# class ly skty ho

# %%
sub1 = int(input("enter your marks: "))
sub2 = int(input("enter your marks: "))
sub3 = int(input("enter your marks: "))
sub4 = int(input("enter your marks: "))
sub5 = int(input("enter your marks: "))
obtain_marks = sub1+sub2+sub3+sub4+sub5
pec = (obtain_marks/500)*100
grade = ""
result = ""
if sub1>=50:
    if sub2>=50:
        if sub3>=50:
            if sub4>=50:
                if sub5 >=50:
                    result = "Pass "
                else:
                    result = "Fail"
            else:
                result = "Fail"
        else:
            result = "Fail"
    else:
        result = "Fail"
else:
    result = "Fail"

if pec >= 90:
    grade = "A+"
elif pec>=80:
    grade = "B"
elif pec>=70:
    grade = "C"
elif pec>=60:
    grade = "D"
else:
    grade = "Fail"
    
    
print(f"""
      total Marks :    500
      obtain Marks :   {obtain_marks}
      percentage :     {pec}
      Grade     :      {grade} 
      overall result :   {result}
      """)
# Out:
# enter your marks: 90
# enter your marks: 90
# enter your marks: 40
# enter your marks: 90
# enter your marks: 80
#
#       total Marks :    500
#       obtain Marks :   390
#       percentage :     78.0
#       Grade     :      C
#       overall result :   Fail

# %%
# age?
# gender
# colour?
# hairs/
# hairs length?
# eyes
# hight?
# weight 
# khana banna ata hai?
# region
# language 
# country 
# voice ?
# village ya city
# pahari bato kitna pahari ho?
my_name = input("larky ka nam: ")
larki_nam = input("enter your name :")
humra_jawab = ""
gender = input("male or female?: ")
if gender == "female":
    age = int(input("age kinti hai: )
    if age>=18 and age<=25:
        colour = input("white colour hai??")
        if colour == "white" or "black":
            hairs = input("hair colour bato? ")
            if hairs =="black" or hairs == "brown":
                hairs_length = int(input("kinty feet heein hairs?  "))
                if hairs_length <= 3:
                    height = int(input("enter you hight: "))
                    if height <= 5:
                        weight = int(input("enter your weight:   "))
                        if weight <=60:
                            cooking = input("cooking ati hai ya ni? Y/N:   ")  
                            if cooking =="y":
                                language = input("english or urdu:   ")
                                if language=="urdu" or language == "english":
                                    country = input("kaha rethi ho ??: ")
                                    if country == "pakistan" or country =="german":
                                        humra_jawab =  "barat kab ly kr ao"
                                    else:
                                        humra_jawab = "Nahi chiya bahi!!"
                                else:
                                    humra_jawab = "Nahi chiya bahi!!"
                            else:
                                humra_jawab = "Nahi chiya bahi!!"
                        else:
                            humra_jawab = "Nahi chiya bahi!!"
                    else:
                        humra_jawab = "Nahi chiya bahi!!"
                else:
                    humra_jawab = "Nahi chiya bahi!!"
            else:
                humra_jawab = "Nahi chiya bahi!!"
        else:
            humra_jawab = "Nahi chiya bahi!!"
    else:
        humra_jawab = "Nahi chiya bahi!!"
else:
    humra_jawab = "Nahi chiya bahi!!"
    
    

    
    
    

    
    
print(f""" 
      My Name       :     {my_name}
      Larki ka nam  :    {larki_nam}
            ___________________________________
      
              Larky ke  Khawishyat
              
              
    larke ke age jo larky ko chiya : 18-25 and larki ke age :   {age}
    larke ka colour jo larky ko chiya : white or light brown :  {colour}
    larki ka weight jo larky ko chiya : 40-60                 : {weight}
    larki ke hight jo larky ko chiya : 4ft to 5.4ft           : {height}
    
    _____________________________________________________________________

                            happy ending 
                            Best of Luck
                
                 Larky ny han Ke Ya nah    :    {humra_jawab}
      
      """)
# Out:
# larky ka nam furqan
# enter your namefurqan
# male or female?female
# age kinti hai19
# white colour hai?? Y/Ny
# hair colour bato? black
# kinty feet heein hairs?  2
# enter you hight5
# enter your weight?  55
# cooking ati hai ya ni? Y/N:   y
# english or urdu:   english
# kaha rethi ho ??pakistan
#
#       My Name       :     furqan
#       Larki ka nam  :    furqan
#             ___________________________________
#
#               Larky ke  Khawishyat
#
#
#     larke ke age jo larky ko chiya : 18-25 and larki ke age :   19
#     larke ka colour jo larky ko chiya : white or light brown :  y
#     larki ka weight jo larky ko chiya : 40-60                 : 55
#     larki ke hight jo larky ko chiya : 4ft to 5.4ft           : 5
#
#     _____________________________________________________________________
#
#                             happy ending
#                             Best of Luck
#
#                  Larky ny han Ke Ya nah    :    barat kab ly kr ao

# %%
a = int(input("number input: "))
if a>9:
    elif a<9:
        print("equal")
    else:
        print("NONE")
else:
    print("none")
# Out:
#   File "C:\Users\Student\AppData\Local\Temp\ipykernel_7492\1650351185.py", line 3
#     elif a<9:
#     ^
# SyntaxError: invalid syntax
