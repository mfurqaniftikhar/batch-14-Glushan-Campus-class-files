# %% [markdown]
# # if/else
# # elif and else
# # nested if

# %% [markdown]
# # operators
#  - aurthumatic operator >>>>>  +,-,*,/,%,**,//
#  - logical operators   >>>>> and , OR , Not
#  - relactional operators >>>>> ==, !=, >,<,>=,<=
#
#  -  = >>> agar kis chz ko koi value assigin krni ho toh "=". >>>>>> a = 5
#
#  - Assigment operator >>> =, +=, -=, *=, /=

# %%
a = 6

a+=6
a
# Out:
# 12

# %%
a = 3

a+=1
a
# Out:
# 4

# %%
a
# Out:
# 4

# %%
a=+1

# %%
b = 9
b-=8
b
# Out:
# 1

# %% [markdown]
# # in operator
#  - ya check kr rha tha ky jo value user ny de hai wo variable mai hai ya ni hai

# %%
# is , in , is not , in not 

# in operator
a = "python"
"on" in a
# Out:
# True

# %%
# not in  
a = " Python"
print("grape" not in  a)

print("this is IN opertaor :" ,"python" in "grape")
# Out:
# True
# this is IN opertaor : False

# %% [markdown]
# # is , not is
#  - is operator check krta hai ky jo values/variables/collection user ny de hein wo same hein ya ni

# %%
a = 9
b = a
a is b
# Out:
# True

# %%
a = "python"
python_1 = "pythoN"
a  is not python_1 # >>>>   "=="
# Out:
# True

# %%
a == b
# Out:
# True

# %% [markdown]
# # Python Collections
#  - List
#  - tuple
#  - sets
#  - dict

# %% [markdown]
# # Python List
#  - [   ]
#  - mutable >>>> list ky ander agar mujy koi chz change krweani hai toh wo krwa skta hu
#  - [2,"jakja" ,"jak8ha"]

# %%
type("python")
# Out:
# str

# %%
a = ['furqan']

# %%
a.append("abdullah")

# %%
a
# Out:
# ['furqan', 'abdullah']

# %%
print(a,type(a))
# Out:
# ['furqan'] <class 'list'>

# %%
b = "python"

# %%
print(b.capitalize())
b
# Out:
# Python
# 'python'

# %%
username = ["hello@67", 'furqan', 678678]
type(username)
# Out:
# list

# %%
a = "hasdjhasdjhas"


len(a)
# Out:
# 13

# %%
course = ['AI-DS','Graphics degising',"digital marketing",'web and app dev ']

# %%
len(course)
# Out:
# 4

# %%
course.append("agentic-Ai")
course
# Out:
# ['AI-DS',
#  'Graphics degising',
#  'digital marketing',
#  'web and app dev ',
#  'agentic-Ai',
#  'agentic-Ai']

# %%
course.append("agentic-Ai")

# %%
course
# Out:
# ['AI-DS',
#  'Graphics degising',
#  'digital marketing',
#  'web and app dev ',
#  'agentic-Ai',
#  'agentic-Ai',
#  'agentic-Ai']

# %%
len(course)
# Out:
# 7

# %%
course.remove("agentic-Ai")
course
# Out:
# ['AI-DS',
#  'Graphics degising',
#  'digital marketing',
#  'web and app dev ',
#  'agentic-Ai']

# %%
print(course)
# Out:
# ['AI-DS', 'Graphics degising', 'digital marketing', 'web and app dev ', 'agentic-Ai']

# %%
course.reverse()

# %%
course
# Out:
# ['agentic-Ai',
#  'web and app dev ',
#  'digital marketing',
#  'Graphics degising',
#  'AI-DS']

# %%
course.insert(1,"ai and data science")

# %%
course
# Out:
# ['agentic-Ai',
#  'ai and data science',
#  'web and app dev ',
#  'digital marketing',
#  'Graphics degising',
#  'AI-DS']

# %%
course.sort(reverse=True)
course
# Out:
# ['web and app dev ',
#  'digital marketing',
#  'ai and data science',
#  'agentic-Ai',
#  'Graphics degising',
#  'AI-DS']

# %%
course.pop(0)
# Out:
# 'digital marketing'

# %%
course
# Out:
# ['ai and data science', 'agentic-Ai', 'Graphics degising', 'AI-DS']

# %%
course.count("i")
# Out:
# 0

# %%
course.index("agentic")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8440\4109835857.py in <module>
# ----> 1 course.index("agentic")
#
# ValueError: 'agentic' is not in list

# %%
nums = [4,42,45,2,45,5,52,2,544,5,56,2,25,99]

# %%
nums.index(45)
# Out:
# 2

# %% [markdown]
# # list indexing
#  - indexing ka mtlb kia hai list , string ya phir kini b collection ke kisi value ko us ke jygha sy access krna
#
#  -          ve+     -4                  -3                -2                -1
#  -          ['ai and data science', 'agentic-Ai', 'Graphics degising', 'AI-DS']
# ​
#  - start with >> ve+ 0 ,                   1     ,    2                 ,    3
#
# - aik time py aik he value ko access kr skty hein

# %%
course
# Out:
# ['ai and data science', 'agentic-Ai', 'Graphics degising', 'AI-DS']

# %%
course[0]
# Out:
# 'ai and data science'
