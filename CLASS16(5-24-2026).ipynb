# %% [markdown]
# # finally

# %%
try:
    a = int(input("enter a NBR: "))
    b= nt(input("enter a NBR: "))
    c = a/b
    print(c)
except Exception as e:
    print(9+8)
finally:
    print(a+b)
# Out:
# enter a NBR: 9
# 17
# 15

# %%
try:
    res = 10 / 0
except ZeroDivisionError as e :
    print(e)
print(res)
# Out:
# division by zero
# Infinity

# %%
ion
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7352\317934744.py in <module>
# ----> 1 ion
#
# NameError: name 'ion' is not defined

# %% [markdown]
# # user defined execptions
# ## rasie
#  - use for creating an error

# %%
marks = (90)
if marks < 100:
    raise Exception("hello")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7352\3434996354.py in <module>
#       1 marks = (90)
#       2 if marks < 100:
# ----> 3     raise Exception("hello")
#
# Exception: hello

# %%
num = -3
if num < 0:
    raise Exception("Negative numbers are not allowed")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7352\3109455167.py in <module>
#       1 num = -3
#       2 if num < 0:
# ----> 3     raise Exception("Negative numbers are not allowed")
#
# Exception: Negative numbers are not allowed

# %%
int("hajkha")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7352\4072099596.py in <module>
# ----> 1 int("hajkha")
#
# ValueError: invalid literal for int() with base 10: 'hajkha'

# %%
if 9>8:
    raise Exception("apka number 9 ny bara hai ")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7352\3686716572.py in <module>
#       1 if 9>8:
# ----> 2     raise Exception("apka number 9 ny bara hai ")
#
# Exception: apka number 9 ny bara hai

# %%
class number_error(Exception):
    pass

# %%
try:
    if 9>8:
        raise Exception("apka number 9 ny chota hai ")
except Exception as e:
    print(e)
# Out:
# apka number 9 ny chota hai

# %%
student_age = int(input("enter your age"))
if (student_age>=15) and (student_age<=19):
    print("apka ab admisson test hoga")
else:
    raise Exception("APKA BOHOT BOHOT SHUKRIA APKO ADMISSION NI MILY GA")
# Out:
# enter your age21
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15876\889204938.py in <module>
#       3     print("apka ab admisson test hoga")
#       4 else:
# ----> 5     raise Exception("APKA BOHOT BOHOT SHUKRIA APKO ADMISSION NI MILY GA")
#       6
#
# Exception: APKA BOHOT BOHOT SHUKRIA APKO ADMISSION NI MILY GA

# %%
class CHUTI_BAND_HAI_TUMHRI(Exception):
    pass

# %%
try:
    student_name =input("enter your name ")
    if len(student_name)<=5:
        print("bhag jao")
    else:
        raise CHUTI_BAND_HAI_TUMHRI("ok hai?")
except Exception as e:
    pass
finally:
    print("sab ka off hai ")

# %% [markdown]
# # OOP!
#  - object orianted programing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Person:
    # characterstics / proprites / atturtibtes / variables
    hair_colour = "black"
    eyes_colour = "blue"
    skin_colour = "white"
    weight = "55KGs"
    hight  = "6feet"
    
    #actions / behaviour
    def eat(self):
        print("Eating....")
    def walk(self):
        print("Walking....")
    def Sleep(self):
        print("Sleep....")
    def Playing(self):
        print("Playing....")
    def Study(self):
        print("Eating....")

# %%
# object is an instance of classes
# it will ne a copy of class 
# it will follow the class rules
p1 = Person()
p2 = Person()
p3 = Person()
p4 = Person()

# %%
p1.Sleep()
# Out:
# Sleep....

# %%
p2.Sleep()
# Out:
# Sleep....

# %%
p3.walk()
# Out:
# Walking....

# %%
p2.eat()
# Out:
# Eating....
